# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="380" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Data Visualization Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be focusing on the visualization of data.
#
# The data set will be presented to you in the form of a RDBMS.
#
# You will have to use SQL queries to extract the data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Demo: How to work with database

# %% [markdown]
# Download database file.

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Out:
# --2024-12-08 21:02:32--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104, 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36679680 (35M) [application/octet-stream]
# Saving to: ‘m4_survey_data.sqlite.5’
#
# m4_survey_data.sqli 100%[===================>]  34.98M  37.9MB/s    in 0.9s
#
# 2024-12-08 21:02:34 (37.9 MB/s) - ‘m4_survey_data.sqlite.5’ saved [36679680/36679680]

# %% [markdown]
# Connect to the database.

# %%
import sqlite3
conn = sqlite3.connect("m4_survey_data.sqlite") # open a database connection

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Demo: How to run an sql query

# %%
# print how many rows are there in the table named 'master'
QUERY = """
SELECT COUNT(*)
FROM master
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df = pd.read_sql_query(QUERY,conn)
df.head()
# Out:
#    COUNT(*)
# 0     11398

# %% [markdown]
# ## Demo: How to list all tables

# %%
# print all the tables names in the database
QUERY = """
SELECT name as Table_Name FROM
sqlite_master WHERE
type = 'table'
"""
# the read_sql_query runs the sql query and returns the data as a dataframe
pd.read_sql_query(QUERY,conn)
# Out:
#                 Table_Name
# 0                 EduOther
# 1                  DevType
# 2                  LastInt
# 3               JobFactors
# 4                 WorkPlan
# 5            WorkChallenge
# 6       LanguageWorkedWith
# 7   LanguageDesireNextYear
# 8       DatabaseWorkedWith
# 9   DatabaseDesireNextYear
# 10      PlatformWorkedWith
# 11  PlatformDesireNextYear
# 12      WebFrameWorkedWith
# 13  WebFrameDesireNextYear
# 14      MiscTechWorkedWith
# 15  MiscTechDesireNextYear
# 16              DevEnviron
# 17              Containers
# 18               SOVisitTo
# 19            SONewContent
# 20                  Gender
# 21               Sexuality
# 22               Ethnicity
# 23                  master

# %% [markdown]
# ## Demo: How to run a group by query

# %%
QUERY = """
SELECT Age,COUNT(*) as count
FROM master
group by age
order by age
"""
pd.read_sql_query(QUERY,conn)
# Out:
#      Age  count
# 0    NaN    287
# 1   16.0      3
# 2   17.0      6
# 3   18.0     29
# 4   19.0     78
# 5   20.0    109
# 6   21.0    203
# 7   22.0    406
# 8   23.0    581
# 9   24.0    679
# 10  25.0    738
# 11  26.0    720
# 12  27.0    724
# 13  28.0    787
# 14  29.0    697
# 15  30.0    651
# 16  31.0    531
# 17  32.0    489
# 18  33.0    483
# 19  34.0    395
# 20  35.0    393
# 21  36.0    308
# 22  37.0    280
# 23  38.0    279
# 24  39.0    232
# 25  40.0    187
# 26  41.0    136
# 27  42.0    162
# 28  43.0    100
# 29  44.0     95
# 30  45.0     85
# 31  46.0     66
# 32  47.0     68
# 33  48.0     64
# 34  49.0     66
# 35  50.0     57
# 36  51.0     29
# 37  52.0     41
# 38  53.0     32
# 39  54.0     26
# 40  55.0     13
# 41  56.0     16
# 42  57.0     11
# 43  58.0     12
# 44  59.0     11
# 45  60.0      2
# 46  61.0     10
# 47  62.0      5
# 48  63.0      7
# 49  65.0      2
# 50  66.0      1
# 51  67.0      1
# 52  69.0      1
# 53  71.0      2
# ...

# %% [markdown]
# ## Demo: How to describe a table

# %%
table_name = 'master'  # the table you wish to describe

QUERY = """
SELECT sql FROM sqlite_master
WHERE name= '{}'
""".format(table_name)

df = pd.read_sql_query(QUERY,conn)
print(df.iat[0,0])
# Out:
# CREATE TABLE "master" (
# "index" INTEGER,
#   "Respondent" INTEGER,
#   "MainBranch" TEXT,
#   "Hobbyist" TEXT,
#   "OpenSourcer" TEXT,
#   "OpenSource" TEXT,
#   "Employment" TEXT,
#   "Country" TEXT,
#   "Student" TEXT,
#   "EdLevel" TEXT,
#   "UndergradMajor" TEXT,
#   "OrgSize" TEXT,
#   "YearsCode" TEXT,
#   "Age1stCode" TEXT,
#   "YearsCodePro" TEXT,
#   "CareerSat" TEXT,
#   "JobSat" TEXT,
#   "MgrIdiot" TEXT,
#   "MgrMoney" TEXT,
#   "MgrWant" TEXT,
#   "JobSeek" TEXT,
#   "LastHireDate" TEXT,
#   "FizzBuzz" TEXT,
#   "ResumeUpdate" TEXT,
#   "CurrencySymbol" TEXT,
#   "CurrencyDesc" TEXT,
#   "CompTotal" REAL,
#   "CompFreq" TEXT,
#   "ConvertedComp" REAL,
#   "WorkWeekHrs" REAL,
#   "WorkRemote" TEXT,
#   "WorkLoc" TEXT,
#   "ImpSyn" TEXT,
#   "CodeRev" TEXT,
#   "CodeRevHrs" REAL,
#   "UnitTests" TEXT,
#   "PurchaseHow" TEXT,
#   "PurchaseWhat" TEXT,
#   "OpSys" TEXT,
#   "BlockchainOrg" TEXT,
#   "BlockchainIs" TEXT,
#   "BetterLife" TEXT,
#   "ITperson" TEXT,
# ...

# %%
QUERY = """
        SELECT DevType, COUNT(*) as count
        FROM DevType
        GROUP BY DevType
        ORDER BY count 
        DESC
        LIMIT 5
        """
df_test = pd.read_sql_query(QUERY, conn)
df_test
# Out:
#                                          DevType  count
# 0                          Developer, full-stack   6928
# 1                            Developer, back-end   6290
# 2                           Developer, front-end   3920
# 3  Developer, desktop or enterprise applications   2575
# 4                              Developer, mobile   1959

# %%
QUERY = """
        SELECT DevType, COUNT(*) as count
        FROM DevType
        GROUP BY DevType
        ORDER BY count 
        DESC
        LIMIT 5
        """
df_test = pd.read_sql_query(QUERY, conn)

df_test.set_index('DevType', inplace=True)    
colors_list = ['red', 'green', 'blue', 'orange', 'purple']
df_test['count'].plot(kind='pie', figsize=(10,6), autopct='%1.1f%%', labels=None, startangle=90, colors=colors_list, shadow=True, pctdistance=1.12, explode=(0.1, 0, 0, 0, 0)  )

plt.legend(labels=df_test.index, loc='upper right', bbox_to_anchor=(1.30, 1),)
plt.title('Top 5 Developer Areas Respondents Work In') 
plt.axis('equal')
plt.show()

# %% [markdown]
# # Hands-on Lab

# %% [markdown]
# ## Visualizing distribution of data

# %% [markdown]
# ### Histograms

# %% [markdown]
# Plot a histogram of `ConvertedComp.`

# %%
# your code goes here
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

QUERY = """
    SELECT  Respondent, ConvertedComp
    FROM master
    """
df_hist = pd.read_sql_query(QUERY, conn)
df_hist['ConvertedComp'].plot(kind='hist', figsize=(8, 6), alpha=1.0)
plt.title('Converted Compensation')
plt.xlabel('Compensation in USD')
plt.ylabel('Respondents')
plt.show()

# %% [markdown]
# ### Box Plots

# %% [markdown]
# Plot a box plot of `Age.`

# %%
# your code goes here
QUERY = """ SELECT Respondent, Age
            FROM master
        """
df_age = pd.read_sql_query(QUERY, conn)
df_age['Age'].plot(kind='box')
plt.title('Age of Respondents')
plt.ylabel('Respondent')

plt.show()

# %% [markdown]
# ## Visualizing relationships in data

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# Create a scatter plot of `Age` and `WorkWeekHrs.`

# %%
# your code goes here
QUERY = """ SELECT WorkWeekHrs, Age
            FROM master
        """
df_age_hours = pd.read_sql_query(QUERY, conn)
df_age_hours.plot(kind='scatter', x='Age', y='WorkWeekHrs', figsize=(10,6), color='darkblue')
plt.title('Age vs Hours Worked during Week')
plt.xlabel('Age')
plt.ylabel('Hours Worked/Week')

plt.show()

# %% [markdown]
# ### Bubble Plots

# %% [markdown]
# Create a bubble plot of `WorkWeekHrs` and `CodeRevHrs`, use `Age` column as bubble size.

# %%
# your code goes here
QUERY = """ SELECT CodeRevHrs, WorkWeekHrs, Age
            FROM master
        """
df_bubble = pd.read_sql_query(QUERY, conn)

sns.scatterplot(data=df_bubble, x='WorkWeekHrs', y='CodeRevHrs', size='Age', hue='Age', color='green', alpha=1.0, sizes=(100, 8))
plt.title('WorkWeekHrs, CodeRevHrs vs Age')
plt.xlabel('Work Week Hours')
plt.ylabel('CodeRevHrs')
plt.show()

# %% [markdown]
# ## Visualizing composition of data

# %% [markdown]
# ### Pie Charts

# %%
#Create a pie chart of the top 5 programming languages that respondents wish to lean next year. Label the pie chart with database names. Display percentages of each database on the pie chart.

QUERY = """
        SELECT LanguageDesireNextYear, count(*) as count
        FROM LanguageDesireNextYear
        GROUP BY LanguageDesireNextYear
        ORDER BY count(LanguageDesireNextYear)
        DESC
        LIMIT 5
        """

df_lang = pd.read_sql_query(QUERY, conn)
df_lang.set_index('LanguageDesireNextYear', inplace=True)

colors_list = ['red', 'green', 'blue', 'orange', 'purple']
df_lang['count'].plot(kind='pie', figsize=(10,6), autopct='%1.10f%%', labels=None, startangle=90, colors=colors_list, shadow=True, pctdistance=1.12)


plt.legend(labels=df_lang.index, loc='upper right')
plt.title('Top 5 Programmin Languages Respondents Wish To Learn') 
plt.axis('equal')
plt.show()

# %%
#How many respondents indicated they currently work with 'SQL'.

QUERY = """
        SELECT LanguageWorkedWith, count(*) as count
        FROM LanguageWorkedWith
        GROUP BY LanguageWorkedWith
        ORDER BY count(LanguageWorkedWith)
        DESC
        LIMIT 5        
        """

df_lang_worked_with = pd.read_sql_query(QUERY, conn)
df_lang_worked_with.set_index('LanguageWorkedWith', inplace=True)
print(df_lang_worked_with)    
 
df_lang_worked_with['count'].plot(kind='pie', figsize=(10,6), autopct='%1.1f%%', labels=None, startangle=90, colors=colors_list, shadow=True, pctdistance=1.12, explode=(0, 0, 0.1, 0, 0)  )

plt.legend(labels=df_lang_worked_with.index, loc='upper right')
plt.title('Top 5 Programming Languages Respondents Work With') 
plt.axis('equal')
plt.show()
# Out:
#                        count
# LanguageWorkedWith
# JavaScript              8687
# HTML/CSS                7830
# SQL                     7106
# Bash/Shell/PowerShell   4642
# Python                  4542

# %%
#Show how many respondents indicated that they work on 'MySQL' only

QUERY = """
        SELECT Respondent, DatabaseWorkedWith, COUNT(*) as count
        FROM DatabaseWorkedWith
        GROUP BY Respondent
        HAVING count = 1
            AND DatabaseWorkedWith = 'MySQL'
                                    
       """
df_MySQL = pd.read_sql_query(QUERY, conn)
print('The number of Respondents working with MySQL only is:', df_MySQL.shape[0])
# Out:
# The number of Respondents working with MySQL only is: 474

# %%
#Create a pie chart of the top 5 databases that respondents wish to learn next year. Label the pie chart with database names. Display percentages of each database on the pie chart.

# your code goes here
QUERY = """ 
SELECT DatabaseDesireNextYear, count(*) as count
from DatabaseDesireNextYear 
GROUP BY DatabaseDesireNextYear
ORDER BY count(DatabaseDesireNextYear) 
DESC
LIMIT 5

""" 

df=pd.read_sql_query(QUERY,conn)  
df.set_index('DatabaseDesireNextYear', inplace=True) 
colors_list=['gold', 'green', 'coral', 'skyblue', 'pink']

df['count'].plot(kind='pie', figsize=(10,6), autopct='%1.1f%%', labels=None, startangle=90, colors=colors_list, shadow=True, pctdistance=1.12)  

plt.legend(labels=df.index, loc='upper right')
plt.title('Top 5 Databases Respondents Wish To Learn') 
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Stacked Charts

# %% [markdown]
# Create a stacked chart of median `WorkWeekHrs` and `CodeRevHrs` for the age group 30 to 35.

# %%
# your code goes here

QUERY = """ SELECT WorkWeekHrs, CodeRevHrs, Age
            FROM master
            WHERE Age BETWEEN 30 AND 35
        """
df_stacked = pd.read_sql_query(QUERY, conn)
df_stacked_2 = df_stacked.groupby('Age').median()

df_stacked_2.plot(kind='bar', figsize=(15, 5), stacked=True)
plt.xlabel('Age')
plt.ylabel('Hours')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title('WorkWeekHrs and CodeRevHrs Vs Age')
plt.show()

# %% [markdown]
# ## Visualizing comparison of data

# %% [markdown]
# ### Line Chart

# %% [markdown]
# Plot the median `ConvertedComp` for all ages from 45 to 60.

# %%
QUERY = """ SELECT ConvertedComp, Age
            FROM master
            WHERE Age BETWEEN 25 AND 30
        """
df_line2 = pd.read_sql_query(QUERY, conn)
df_line2 = df_line2.loc[(df_line2['Age'] >= 25) & (df_line2['Age'] <= 30)].reset_index().drop(columns=['index'])
df_line2.dropna(inplace=True)
df_line2 = df_line2.groupby('Age', axis=0).median()
df_line2.plot(kind='line', figsize=(15, 5))
plt.xlabel('Age')
plt.ylabel('Compensation')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title('Converted Compensation Age Range 25 - 30')
plt.show()

# %%
# your code goes here
QUERY = """ SELECT ConvertedComp, Age
            FROM master
            WHERE Age BETWEEN 45 AND 60
        """
df_line = pd.read_sql_query(QUERY, conn)

df_line = df_line.loc[(df_line['Age'] >= 45) & (df_line['Age'] <= 60)].reset_index().drop(columns=['index'])
df_line.dropna(inplace=True)
   
df_line = df_line.groupby('Age', axis=0).median()
    
df_line.plot(kind='line', figsize=(15, 5))
plt.xlabel('Age')
plt.ylabel('Compensation')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title('Converted Compensation Age Range 35 -60')
plt.show()

# %% [markdown]
# ### Bar Chart

# %% [markdown]
# Create a horizontal bar chart using column `MainBranch.`

# %%
# your code goes here
QUERY = """
        SELECT MainBranch, COUNT(*) as MainBranch
        FROM master
        GROUP BY MainBranch
        """
df_main = pd.read_sql_query(QUERY, conn)
df_main.plot(kind='barh', figsize=(8, 6), alpha=1.0, color='teal')
plt.title('Where Respondents Work')
plt.xlabel('Number')
plt.ylabel('Location 0: Not at the Main Branch\n' + 'Location 1: Main Branch')
plt.show()

# %% [markdown]
# Close the database connection.

# %%
conn.close()

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).

# %% [markdown]
# <!--## Change Log

# %% [markdown]
# <!--| Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |--!>
